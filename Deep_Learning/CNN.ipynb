# %% [markdown]
# # Preprocessing for CNN

# %% [markdown]
# Importing the libraries

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
tf.__version__
# Out:
# '2.8.0'

# %% [markdown]
# Preprocessing

# %%
#3-d transfromations
#url = https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator

#Data augmentation
train_datagen = ImageDataGenerator(
        rescale=1./255, #feature scaling of each pixel of each image as each pixel is of range (0,255)
        shear_range=0.2, #image augmentation(Shear angle in counter-clockwise direction in degrees)
        zoom_range=0.2,
        horizontal_flip=True) #last three steps is to preent image overfitting

#Preprocessing dataset into CNN
training_set = train_datagen.flow_from_directory(
        "/content/drive/MyDrive/Machine Learning A-Z (Codes and Datasets)/Part 8 - Deep Learning/Section+40+-+Convolutional+Neural+Networks+(CNN)/Section 40 - Convolutional Neural Networks (CNN)/dataset/training_set",
        target_size=(64, 64), #Size of each image that can be loaded into CNN model
        batch_size=32, #No of images passed in one go
        class_mode='binary') #cat or dog
# Out:
# Found 4972 images belonging to 2 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1./255) #calling data augmentation function

#Preprocessing test set into CNN
validation_generator = test_datagen.flow_from_directory(
        "/content/drive/MyDrive/Machine Learning A-Z (Codes and Datasets)/Part 8 - Deep Learning/Section+40+-+Convolutional+Neural+Networks+(CNN)/Section 40 - Convolutional Neural Networks (CNN)/dataset/test_set",
        target_size=(64, 64),
        batch_size=32,
        class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# # Building the CNN model

# %% [markdown]
# Initialising the CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# Convulation(Reduction of image using multiplication of pixels matrix with filter matrix)

# %%
cnn.add(tf.keras.layers.Conv2D(filters = 32, kernel_size=3, activation = 'relu',input_shape= [64,64,3])) #filters == 32(for classical Model for CNN), kernel=filter matrix size(3x3),input_shape=size of image (3 is for rbg)

# %% [markdown]
# Pooling(Reduction using max pool,min pool or average pool)

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))#2x2 as pool size , strides = steps to be taken for selecting pool,padding is used at end (2ways==ignore/add column of all values=0)

# %% [markdown]
# Adding convulation layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters = 32, kernel_size=3, activation = 'relu')) 
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %% [markdown]
# Flattening(converting 2d reduced pixels into 1d array)

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# Full connection(ANN)

# %%
cnn.add(tf.keras.layers.Dense(units = 128,activation='relu'))

# %% [markdown]
# Output layer

# %%
cnn.add(tf.keras.layers.Dense(units = 1,activation='sigmoid'))

# %% [markdown]
# # Training the CNN model

# %% [markdown]
# Compiling the CNN

# %%
cnn.compile(optimizer = 'adam', metrics = ['accuracy'], loss = 'binary_crossentropy')

# %% [markdown]
# Training the CNN on training set and evaluate on test set

# %%
cnn.fit(x= training_set, validation_data=validation_generator, epochs = 25)
# Out:
# Epoch 1/25
# 156/156 [==============================] - 2611s 17s/step - loss: 0.5053 - accuracy: 0.8005 - val_loss: 0.9575 - val_accuracy: 0.5000
# Epoch 2/25
# 156/156 [==============================] - 48s 309ms/step - loss: 0.4776 - accuracy: 0.8045 - val_loss: 0.8775 - val_accuracy: 0.5000
# Epoch 3/25
# 156/156 [==============================] - 48s 308ms/step - loss: 0.4585 - accuracy: 0.8049 - val_loss: 0.8536 - val_accuracy: 0.5200
# Epoch 4/25
# 156/156 [==============================] - 48s 306ms/step - loss: 0.4434 - accuracy: 0.8111 - val_loss: 0.6686 - val_accuracy: 0.6635
# Epoch 5/25
# 156/156 [==============================] - 48s 307ms/step - loss: 0.4307 - accuracy: 0.8142 - val_loss: 0.6989 - val_accuracy: 0.5795
# Epoch 6/25
# 156/156 [==============================] - 48s 306ms/step - loss: 0.4128 - accuracy: 0.8224 - val_loss: 0.6288 - val_accuracy: 0.6755
# Epoch 7/25
# 156/156 [==============================] - 48s 307ms/step - loss: 0.4021 - accuracy: 0.8290 - val_loss: 0.5619 - val_accuracy: 0.7215
# Epoch 8/25
# 156/156 [==============================] - 48s 306ms/step - loss: 0.3988 - accuracy: 0.8317 - val_loss: 0.6833 - val_accuracy: 0.6325
# Epoch 9/25
# 156/156 [==============================] - 48s 305ms/step - loss: 0.3867 - accuracy: 0.8367 - val_loss: 0.6619 - val_accuracy: 0.6595
# Epoch 10/25
# 156/156 [==============================] - 48s 305ms/step - loss: 0.3778 - accuracy: 0.8389 - val_loss: 0.5453 - val_accuracy: 0.7355
# Epoch 11/25
# 156/156 [==============================] - 47s 304ms/step - loss: 0.3643 - accuracy: 0.8431 - val_loss: 0.6513 - val_accuracy: 0.6985
# Epoch 12/25
# 156/156 [==============================] - 48s 305ms/step - loss: 0.3655 - accuracy: 0.8492 - val_loss: 0.5608 - val_accuracy: 0.7345
# Epoch 13/25
# 156/156 [==============================] - 48s 304ms/step - loss: 0.3519 - accuracy: 0.8540 - val_loss: 0.6494 - val_accuracy: 0.6955
# Epoch 14/25
# 156/156 [==============================] - 48s 306ms/step - loss: 0.3401 - accuracy: 0.8552 - val_loss: 0.6099 - val_accuracy: 0.7175
# Epoch 15/25
# 156/156 [==============================] - 47s 304ms/step - loss: 0.3318 - accuracy: 0.8586 - val_loss: 0.7586 - val_accuracy: 0.6790
# Epoch 16/25
# 156/156 [==============================] - 48s 307ms/step - loss: 0.3262 - accuracy: 0.8660 - val_loss: 0.5848 - val_accuracy: 0.7410
# Epoch 17/25
# 156/156 [==============================] - 48s 305ms/step - loss: 0.3182 - accuracy: 0.8644 - val_loss: 0.6323 - val_accuracy: 0.7095
# Epoch 18/25
# 156/156 [==============================] - 48s 310ms/step - loss: 0.3069 - accuracy: 0.8719 - val_loss: 0.5924 - val_accuracy: 0.7250
# Epoch 19/25
# 156/156 [==============================] - 48s 309ms/step - loss: 0.3050 - accuracy: 0.8725 - val_loss: 0.5319 - val_accuracy: 0.7645
# Epoch 20/25
# 156/156 [==============================] - 49s 313ms/step - loss: 0.2955 - accuracy: 0.8769 - val_loss: 0.5827 - val_accuracy: 0.7395
# Epoch 21/25
# 156/156 [==============================] - 48s 306ms/step - loss: 0.2820 - accuracy: 0.8852 - val_loss: 0.6047 - val_accuracy: 0.7440
# Epoch 22/25
# 156/156 [==============================] - 48s 306ms/step - loss: 0.2790 - accuracy: 0.8852 - val_loss: 0.6963 - val_accuracy: 0.7085
# Epoch 23/25
# 156/156 [==============================] - 48s 305ms/step - loss: 0.2644 - accuracy: 0.8868 - val_loss: 0.5288 - val_accuracy: 0.7770
# Epoch 24/25
# 156/156 [==============================] - 47s 304ms/step - loss: 0.2617 - accuracy: 0.8918 - val_loss: 0.6692 - val_accuracy: 0.7355
# Epoch 25/25
# 156/156 [==============================] - 48s 306ms/step - loss: 0.2475 - accuracy: 0.8982 - val_loss: 0.7839 - val_accuracy: 0.7150

# %% [markdown]
# # Making the Single prediction

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img("/content/drive/MyDrive/Machine Learning A-Z (Codes and Datasets)/Part 8 - Deep Learning/Section+40+-+Convolutional+Neural+Networks+(CNN)/Section 40 - Convolutional Neural Networks (CNN)/dataset/single_prediction/cat_or_dog_1.jpg", target_size = (64, 64))
test_image = image.img_to_array(test_image) #converison to 1-d array
test_image = np.expand_dims(test_image, axis = 0) 
result = cnn.predict(test_image)
print(result)
training_set.class_indices
if result[0][0] == 1:
    prediction = 'dog'
else:
    prediction = 'cat'
print(prediction)
# Out:
# [[1.]]
# dog

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img("/content/drive/MyDrive/Machine Learning A-Z (Codes and Datasets)/Part 8 - Deep Learning/Section+40+-+Convolutional+Neural+Networks+(CNN)/Section 40 - Convolutional Neural Networks (CNN)/dataset/single_prediction/cat_or_dog_2.jpg", target_size = (64, 64))
test_image = image.img_to_array(test_image) #converison to 1-d array
test_image = np.expand_dims(test_image, axis = 0) 
result = cnn.predict(test_image)
print(result)
training_set.class_indices
if result[0][0] == 1:
    prediction = 'dog'
else:
    prediction = 'cat'
print(prediction)
# Out:
# [[0.]]
# cat

# %%
# https://medium.com/neuronio/understanding-convnets-cnn-712f2afe4dd3
